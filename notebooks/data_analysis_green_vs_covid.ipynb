# %% [markdown]
# # T

# %%
from pyspark.sql import SparkSession

# Create a spark session (which will run spark jobs)
spark = (
    SparkSession.builder.appName("MAST30034 XT Project 1")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .getOrCreate()
)
# Out:
# 22/07/29 15:50:12 WARN Utils: Your hostname, Polaris resolves to a loopback address: 127.0.1.1; using 172.17.237.8 instead (on interface eth0)
# 22/07/29 15:50:12 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/07/29 15:50:13 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# read in the taxi data
yellow_df = spark.read.parquet("../data/raw/tlc/yellow/")

# %%
taxi_zones_df = spark.read.csv('../data/raw/tlc/taxi_zones.csv')

# %%
taxi_zones_df.limit(5)
# Out:
# +--------+---------------+--------------------+-----------------+--------------------+----------+---------+
# |     _c0|            _c1|                 _c2|              _c3|                 _c4|       _c5|      _c6|
# +--------+---------------+--------------------+-----------------+--------------------+----------+---------+
# |OBJECTID|     Shape_Leng|            the_geom|       Shape_Area|                zone|LocationID|  borough|
# |       1| 0.116357453189|MULTIPOLYGON (((-...|  0.0007823067885|      Newark Airport|         1|      EWR|
# |       2|  0.43346966679|MULTIPOLYGON (((-...| 0.00486634037837|         Jamaica Bay|         2|   Queens|
# |       3|0.0843411059012|MULTIPOLYGON (((-...|0.000314414156821|Allerton/Pelham G...|         3|    Bronx|
# |       4|0.0435665270921|MULTIPOLYGON (((-...|0.000111871946192|       Alphabet City|         4|Manhattan|
# +--------+---------------+--------------------+-----------------+--------------------+----------+---------+

# %%
set(taxi_zones_df.select("_c6").collect())
# Out:
# {Row(_c6='Bronx'),
#  Row(_c6='Brooklyn'),
#  Row(_c6='EWR'),
#  Row(_c6='Manhattan'),
#  Row(_c6='Queens'),
#  Row(_c6='Staten Island'),
#  Row(_c6='borough')}
